# %%
def tuika(some_list):
  some_list.append(5)
  return some_list


a = 85
new_a = tuika(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-7f756988bfeb> in <module>()
#       5
#       6 a = 85
# ----> 7 new_a = tuika(a)
#
# <ipython-input-1-7f756988bfeb> in tuika(some_list)
#       1 def tuika(some_list):
# ----> 2   some_list.append(5)
#       3   return some_list
#       4
#       5
#
# AttributeError: 'int' object has no attribute 'append'
